# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="companydb",
    user="postgres",
    password="142536",
    host="localhost",
    port="5432"
)

cur = conn.cursor()

employees = [
    ("John", "Smith", "john.smith@example.com", "Engineering", 85000, "2023-01-15"),
    ("Sarah", "Johnson", "sarah.johnson@example.com", "Marketing", 72000, "2022-06-10"),
    ("Michael", "Brown", "michael.brown@example.com", "Finance", 90000, "2021-09-20"),
    ("Emily", "Davis", "emily.davis@example.com", "HR", 68000, "2023-03-05"),
    ("David", "Wilson", "david.wilson@example.com", "Engineering", 95000, "2020-11-12")
]

insert_query = """
INSERT INTO employees
(first_name, last_name, email, department, salary, hire_date)
VALUES (%s, %s, %s, %s, %s, %s)
"""

cur.executemany(insert_query, employees)

conn.commit()

print(f"Inserted {len(employees)} rows.")

cur.close()
conn.close()
# Out:
# Inserted 5 rows.

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="companydb",
    user="postgres",
    password="142536",
    host="localhost",
    port="5432"
)

cur = conn.cursor()

cur.execute("SELECT * FROM employees")

rows = cur.fetchall()

for row in rows:
    print(row)

cur.close()
conn.close()
# Out:
# (1, 'John', 'Smith', 'john.smith@example.com', 'Engineering', Decimal('85000.00'), datetime.date(2023, 1, 15))
# (2, 'Sarah', 'Johnson', 'sarah.johnson@example.com', 'Marketing', Decimal('72000.00'), datetime.date(2022, 6, 10))
# (3, 'Michael', 'Brown', 'michael.brown@example.com', 'Finance', Decimal('90000.00'), datetime.date(2021, 9, 20))
# (4, 'Emily', 'Davis', 'emily.davis@example.com', 'HR', Decimal('68000.00'), datetime.date(2023, 3, 5))
# (5, 'David', 'Wilson', 'david.wilson@example.com', 'Engineering', Decimal('95000.00'), datetime.date(2020, 11, 12))
